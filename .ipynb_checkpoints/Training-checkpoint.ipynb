# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
img_size = 256
BATCH_size = 30
epochs = 50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "Defects",
    shuffle = True,
    image_size = (img_size , img_size),
    batch_size = BATCH_size
)
# Out:
# Found 1656 files belonging to 6 classes.

# %%
c_names = dataset.class_names
c_names
# Out:
# ['Crazing', 'Inclusion', 'Patches', 'Pitted', 'Rolled', 'Scratches']

# %%
plt.figure(figsize=(10,10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(c_names[label_batch[i]])
        plt.axis("off")

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 44.800000000000004

# %%
def get_dataset_partitions_tf(ds, test_part = 0.1 , train_part=0.8 , val_part =0.1, shuffle = True ,shuffle_size = 10000):
    ds_size = len(ds)
    
    if shuffle:
        ds = ds.shuffle(shuffle_size , seed =10)
        
    test_size = int(test_part*ds_size)
    train_size = int(train_part*ds_size)
    
    train_ds = ds.take(train_size)
    test_ds = ds.skip(train_size).take(test_size)
    val_ds = ds.skip(train_size).skip(test_size)
    
    return train_ds, test_ds, val_ds

# %%
train_ds, test_ds, val_ds = get_dataset_partitions_tf(dataset)

# %%
len(val_ds)
# Out:
# 7

# %%
train_ds = train_ds.cache().shuffe(1000).prefetch(nbuffer_size = tf.data.AUTOTUNE)
val_ds= val_ds.cache().shuffe(1000).prefetch(nbuffer_size = tf.data.AUTOTUNE)
test_ds= test_ds.cache().shuffe(1000).prefetch(nbuffer_size = tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(img_size,img_size),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
tf.keras.Sequential([
    layers.experimental.preprocessing.Randomflip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
])
